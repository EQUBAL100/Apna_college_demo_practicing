# %% [markdown]
# <a href="https://colab.research.google.com/github/EQUBAL100/Apna_college_demo_practicing/blob/main/mumax3_TRNG_pc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mumax3 in google colaboratory**

# %% [markdown]
# # About Google colaboratory

# %% [markdown]
# Google colaboratory is a research tool mainly used by researchers in the field of machine learning. The main purpose of this tool is to run python code in jupyter notebooks. These notebooks run on a virtual linux machine private to your gmail account. This means that you will need a gmail account to execute programs in a google colaboratory session. If you have a gmail account you should be able to copy this jupyter notebook to your google drive and execute the code cells.
#
# To run mumax3 simulations, you do not need to write any python code. So you might wonder how we can use this jupyter notebook environment to run mumax3 simulations. The trick here is that you can execute shell commands by typing an exclamation mark followed by the command, as shown in the code cell below. If you run this code cell, the shell will print out the operating system of the virtual machine. Having the ability to run shell commands suffices to install and run mumax3 simulations, as demonstrated in the sections below.

# %%
! echo "This machine runs" $(uname)
# Out:
# This machine runs Linux

# %% [markdown]
# # Installing mumax3

# %% [markdown]
# To install mumax3.10 on this virtual machine, you can run the cell below. This might take a few minutes. When the installation is done, you can collapse this section to get a clean workspace.

# %%
# Download the mumax3 binary
try:
    import google.colab
except ImportError:
    pass
else:
    # !wget https://mumax.ugent.be/mumax3-binaries/mumax3.12_linux_cuda12.9.tar.gz
    # !tar -xvf mumax3.12_linux_cuda12.9.tar.gz
    # !rm mumax3.12_linux_cuda12.9.tar.gz
    # !rm -rf mumax3.12 && mv mumax3.12_linux_cuda12.9 mumax3.12
    import os
    os.environ['PATH'] += ":/content/mumax3.12"

# Download an examplary script
# !wget https://raw.githubusercontent.com/JeroenMulkers/mumax3-tutorial/master/standardproblem4.mx3 -O standardproblem4.mx3
# Out:
# --2026-05-04 12:21:23--  https://mumax.ugent.be/mumax3-binaries/mumax3.12_linux_cuda12.9.tar.gz
# Resolving mumax.ugent.be (mumax.ugent.be)... 157.193.40.77
# Connecting to mumax.ugent.be (mumax.ugent.be)|157.193.40.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 287329660 (274M) [application/x-gzip]
# Saving to: ‘mumax3.12_linux_cuda12.9.tar.gz’
#
# mumax3.12_linux_cud 100%[===================>] 274.02M  30.0MB/s    in 9.2s
#
# 2026-05-04 12:21:33 (29.9 MB/s) - ‘mumax3.12_linux_cuda12.9.tar.gz’ saved [287329660/287329660]
#
# mumax3.12_linux_cuda12.9/
# mumax3.12_linux_cuda12.9/LICENSE
# mumax3.12_linux_cuda12.9/mumax3
# mumax3.12_linux_cuda12.9/mumax3-server
# mumax3.12_linux_cuda12.9/mumax3-convert
# mumax3.12_linux_cuda12.9/lib/
# mumax3.12_linux_cuda12.9/lib/libcurand.so.10
# mumax3.12_linux_cuda12.9/lib/libcufft.so.11
# --2026-05-04 12:21:40--  https://raw.githubusercontent.com/JeroenMulkers/mumax3-tutorial/master/standardproblem4.mx3
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 258 [text/plain]
# Saving to: ‘standardproblem4.mx3’
#
# standardproblem4.mx 100%[===================>]     258  --.-KB/s    in 0s
#
# 2026-05-04 12:21:40 (5.39 MB/s) - ‘standardproblem4.mx3’ saved [258/258]

# %% [markdown]
# # Running a mumax3 script

# %% [markdown]
# You can open the filebrowser for this virtual machine on the left side of this page. Here you should see a mumax3 script named standardproblem4.mx3. You should be able to open this file with a double click. To execute the script run the code cell below.

# %%
# !mumax3 Vortex_TRNG.mx3
# Out:
# //mumax 3.12 [linux_amd64 go1.22.4(gc) CUDA-12.9]
# //commit hash: 6e5c98bb
# //CPU info: Intel(R) Xeon(R) CPU @ 2.00GHz, Cores: 1, MHz: 2000.184
# //GPU info: Tesla T4(14912MB), CUDA Driver 13.0, cc=7.5, using cc=75 PTX
# //OS  info: Ubuntu 22.04.5 LTS, Hostname: 548532fcdadb
# //Timestamp: 2026-05-04 13:03:25
# //(c) Arne Vansteenkiste, Dynamat LAB, Ghent University, Belgium
# //This is free software without any warranty. See license.txt
# //********************************************************************//
# //  If you use mumax in any work or publication,                      //
# //  we kindly ask you to cite the references in references.bib        //
# //********************************************************************//
# //output directory: Vortex_TRNG.out/
# //starting GUI at http://127.0.0.1:35367
# SetGridsize(64, 64, 1)
# SetCellsize(5e-9, 5e-9, 10e-9)
# setgeom(circle(200e-9))
# // Initializing geometry 1 %
# // Initializing geometry 100 %
# Msat = 8e5
# Aex = 1.3e-11
# alpha = 0.5
# Temp = 300
# nRuns := 50
# for i := 0; i < nRuns; i++ {
# 	m = uniform(1, 0, 0)
# 	B_ext = vector(0, 0, 0.05)
# 	run(1e-9)
# 	B_ext = vector(0, 0, 0)
# 	run(2e-9)
# 	relax()
# 	save(m)
# }
# //Using cached kernel: /tmp/mumax3kernel_[64 64 1]_[0 0 0]_[5e-09 5e-09 1e-08]_6_
# //********************************************************************//
# //Please cite the following references, relevant for your simulation. //
# //See bibtex file in output folder for justification.                 //
# //********************************************************************//
# //   * Vansteenkiste et al., AIP Adv. 4, 107133 (2014).
# //   * Leliaert et al., AIP Adv. 7, 125010 (2017).

# %% [markdown]
# If you ran the cell above, then there should be a directory named standardproblem4.out (you might need to click on the refresh button in the filebrowser). This directory contains the output files of the simulation. mumax3-convert can now be used to convert the ovf files to images, as demonstrated in the cell below.

# %%
# !mumax3-convert -png Vortex_TRNG.out/*.ovf
# Out:
# Vortex_TRNG.out/m000000.ovf
# Vortex_TRNG.out/m000001.ovf
# Vortex_TRNG.out/m000002.ovf
# Vortex_TRNG.out/m000003.ovf
# Vortex_TRNG.out/m000004.ovf
# Vortex_TRNG.out/m000005.ovf
# Vortex_TRNG.out/m000006.ovf
# Vortex_TRNG.out/m000007.ovf
# Vortex_TRNG.out/m000008.ovf
# Vortex_TRNG.out/m000009.ovf
# Vortex_TRNG.out/m000010.ovf
# Vortex_TRNG.out/m000011.ovf
# Vortex_TRNG.out/m000012.ovf
# Vortex_TRNG.out/m000013.ovf
# Vortex_TRNG.out/m000014.ovf
# Vortex_TRNG.out/m000015.ovf
# Vortex_TRNG.out/m000016.ovf
# Vortex_TRNG.out/m000017.ovf
# Vortex_TRNG.out/m000018.ovf
# Vortex_TRNG.out/m000019.ovf
# Vortex_TRNG.out/m000020.ovf
# Vortex_TRNG.out/m000021.ovf
# Vortex_TRNG.out/m000022.ovf
# Vortex_TRNG.out/m000023.ovf
# Vortex_TRNG.out/m000024.ovf
# Vortex_TRNG.out/m000025.ovf
# Vortex_TRNG.out/m000026.ovf
# Vortex_TRNG.out/m000027.ovf
# Vortex_TRNG.out/m000028.ovf
# Vortex_TRNG.out/m000029.ovf
# Vortex_TRNG.out/m000030.ovf
# Vortex_TRNG.out/m000031.ovf
# Vortex_TRNG.out/m000032.ovf
# Vortex_TRNG.out/m000033.ovf
# Vortex_TRNG.out/m000034.ovf
# Vortex_TRNG.out/m000035.ovf
# Vortex_TRNG.out/m000036.ovf
# Vortex_TRNG.out/m000037.ovf
# Vortex_TRNG.out/m000038.ovf
# Vortex_TRNG.out/m000039.ovf
# Vortex_TRNG.out/m000040.ovf
# Vortex_TRNG.out/m000041.ovf
# Vortex_TRNG.out/m000042.ovf
# Vortex_TRNG.out/m000043.ovf
# Vortex_TRNG.out/m000044.ovf
# Vortex_TRNG.out/m000045.ovf
# Vortex_TRNG.out/m000046.ovf
# Vortex_TRNG.out/m000047.ovf
# Vortex_TRNG.out/m000048.ovf
# Vortex_TRNG.out/m000049.ovf
# [ ok ] Vortex_TRNG.out/m000000.ovf	-> Vortex_TRNG.out/m000000.png
# [ ok ] Vortex_TRNG.out/m000002.ovf	-> Vortex_TRNG.out/m000002.png
# [ ok ] Vortex_TRNG.out/m000001.ovf	-> Vortex_TRNG.out/m000001.png
# [ ok ] Vortex_TRNG.out/m000005.ovf	-> Vortex_TRNG.out/m000005.png
# [ ok ] Vortex_TRNG.out/m000004.ovf	-> Vortex_TRNG.out/m000004.png
# [ ok ] Vortex_TRNG.out/m000006.ovf	-> Vortex_TRNG.out/m000006.png
# [ ok ] Vortex_TRNG.out/m000003.ovf	-> Vortex_TRNG.out/m000003.png
# [ ok ] Vortex_TRNG.out/m000008.ovf	-> Vortex_TRNG.out/m000008.png
# [ ok ] Vortex_TRNG.out/m000009.ovf	-> Vortex_TRNG.out/m000009.png
# [ ok ] Vortex_TRNG.out/m000011.ovf	-> Vortex_TRNG.out/m000011.png
# [ ok ] Vortex_TRNG.out/m000007.ovf	-> Vortex_TRNG.out/m000007.png
# [ ok ] Vortex_TRNG.out/m000012.ovf	-> Vortex_TRNG.out/m000012.png
# [ ok ] Vortex_TRNG.out/m000014.ovf	-> Vortex_TRNG.out/m000014.png
# [ ok ] Vortex_TRNG.out/m000010.ovf	-> Vortex_TRNG.out/m000010.png
# [ ok ] Vortex_TRNG.out/m000015.ovf	-> Vortex_TRNG.out/m000015.png
# [ ok ] Vortex_TRNG.out/m000013.ovf	-> Vortex_TRNG.out/m000013.png
# [ ok ] Vortex_TRNG.out/m000016.ovf	-> Vortex_TRNG.out/m000016.png
# [ ok ] Vortex_TRNG.out/m000017.ovf	-> Vortex_TRNG.out/m000017.png
# [ ok ] Vortex_TRNG.out/m000019.ovf	-> Vortex_TRNG.out/m000019.png
# [ ok ] Vortex_TRNG.out/m000020.ovf	-> Vortex_TRNG.out/m000020.png
# [ ok ] Vortex_TRNG.out/m000018.ovf	-> Vortex_TRNG.out/m000018.png
# [ ok ] Vortex_TRNG.out/m000021.ovf	-> Vortex_TRNG.out/m000021.png
# [ ok ] Vortex_TRNG.out/m000023.ovf	-> Vortex_TRNG.out/m000023.png
# [ ok ] Vortex_TRNG.out/m000024.ovf	-> Vortex_TRNG.out/m000024.png
# [ ok ] Vortex_TRNG.out/m000022.ovf	-> Vortex_TRNG.out/m000022.png
# [ ok ] Vortex_TRNG.out/m000026.ovf	-> Vortex_TRNG.out/m000026.png
# [ ok ] Vortex_TRNG.out/m000027.ovf	-> Vortex_TRNG.out/m000027.png
# [ ok ] Vortex_TRNG.out/m000028.ovf	-> Vortex_TRNG.out/m000028.png
# [ ok ] Vortex_TRNG.out/m000029.ovf	-> Vortex_TRNG.out/m000029.png
# [ ok ] Vortex_TRNG.out/m000025.ovf	-> Vortex_TRNG.out/m000025.png
# [ ok ] Vortex_TRNG.out/m000031.ovf	-> Vortex_TRNG.out/m000031.png
# [ ok ] Vortex_TRNG.out/m000032.ovf	-> Vortex_TRNG.out/m000032.png
# [ ok ] Vortex_TRNG.out/m000030.ovf	-> Vortex_TRNG.out/m000030.png
# [ ok ] Vortex_TRNG.out/m000034.ovf	-> Vortex_TRNG.out/m000034.png
# [ ok ] Vortex_TRNG.out/m000035.ovf	-> Vortex_TRNG.out/m000035.png
# [ ok ] Vortex_TRNG.out/m000036.ovf	-> Vortex_TRNG.out/m000036.png
# [ ok ] Vortex_TRNG.out/m000037.ovf	-> Vortex_TRNG.out/m000037.png
# [ ok ] Vortex_TRNG.out/m000038.ovf	-> Vortex_TRNG.out/m000038.png
# [ ok ] Vortex_TRNG.out/m000033.ovf	-> Vortex_TRNG.out/m000033.png
# [ ok ] Vortex_TRNG.out/m000040.ovf	-> Vortex_TRNG.out/m000040.png
# [ ok ] Vortex_TRNG.out/m000041.ovf	-> Vortex_TRNG.out/m000041.png
# [ ok ] Vortex_TRNG.out/m000042.ovf	-> Vortex_TRNG.out/m000042.png
# [ ok ] Vortex_TRNG.out/m000043.ovf	-> Vortex_TRNG.out/m000043.png
# [ ok ] Vortex_TRNG.out/m000045.ovf	-> Vortex_TRNG.out/m000045.png
# [ ok ] Vortex_TRNG.out/m000044.ovf	-> Vortex_TRNG.out/m000044.png
# [ ok ] Vortex_TRNG.out/m000046.ovf	-> Vortex_TRNG.out/m000046.png
# [ ok ] Vortex_TRNG.out/m000048.ovf	-> Vortex_TRNG.out/m000048.png
# [ ok ] Vortex_TRNG.out/m000039.ovf	-> Vortex_TRNG.out/m000039.png
# [ ok ] Vortex_TRNG.out/m000049.ovf	-> Vortex_TRNG.out/m000049.png
# [ ok ] Vortex_TRNG.out/m000047.ovf	-> Vortex_TRNG.out/m000047.png
# 50 files converted,  0 skipped,  0 failed

# %% [markdown]
# Convert Binary OVF → ASCII (text OVF2 format)

# %%
# !mumax3-convert -ovf2 text Vortex_TRNG.out/*.ovf
# Out:
# Vortex_TRNG.out/m000000.ovf
# Vortex_TRNG.out/m000001.ovf
# Vortex_TRNG.out/m000002.ovf
# Vortex_TRNG.out/m000003.ovf
# Vortex_TRNG.out/m000004.ovf
# Vortex_TRNG.out/m000005.ovf
# Vortex_TRNG.out/m000006.ovf
# Vortex_TRNG.out/m000007.ovf
# Vortex_TRNG.out/m000008.ovf
# Vortex_TRNG.out/m000009.ovf
# Vortex_TRNG.out/m000010.ovf
# Vortex_TRNG.out/m000011.ovf
# Vortex_TRNG.out/m000012.ovf
# Vortex_TRNG.out/m000013.ovf
# Vortex_TRNG.out/m000014.ovf
# Vortex_TRNG.out/m000015.ovf
# Vortex_TRNG.out/m000016.ovf
# Vortex_TRNG.out/m000017.ovf
# Vortex_TRNG.out/m000018.ovf
# Vortex_TRNG.out/m000019.ovf
# Vortex_TRNG.out/m000020.ovf
# Vortex_TRNG.out/m000021.ovf
# Vortex_TRNG.out/m000022.ovf
# Vortex_TRNG.out/m000023.ovf
# Vortex_TRNG.out/m000024.ovf
# Vortex_TRNG.out/m000025.ovf
# Vortex_TRNG.out/m000026.ovf
# Vortex_TRNG.out/m000027.ovf
# Vortex_TRNG.out/m000028.ovf
# Vortex_TRNG.out/m000029.ovf
# Vortex_TRNG.out/m000030.ovf
# Vortex_TRNG.out/m000031.ovf
# Vortex_TRNG.out/m000032.ovf
# Vortex_TRNG.out/m000033.ovf
# Vortex_TRNG.out/m000034.ovf
# Vortex_TRNG.out/m000035.ovf
# Vortex_TRNG.out/m000036.ovf
# Vortex_TRNG.out/m000037.ovf
# Vortex_TRNG.out/m000038.ovf
# Vortex_TRNG.out/m000039.ovf
# Vortex_TRNG.out/m000040.ovf
# Vortex_TRNG.out/m000041.ovf
# Vortex_TRNG.out/m000042.ovf
# Vortex_TRNG.out/m000043.ovf
# Vortex_TRNG.out/m000044.ovf
# Vortex_TRNG.out/m000045.ovf
# Vortex_TRNG.out/m000046.ovf
# Vortex_TRNG.out/m000047.ovf
# Vortex_TRNG.out/m000048.ovf
# Vortex_TRNG.out/m000049.ovf
# [fail] Vortex_TRNG.out/m000000.ovf	-> Vortex_TRNG.out/m000000.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000002.ovf	-> Vortex_TRNG.out/m000002.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000001.ovf	-> Vortex_TRNG.out/m000001.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000004.ovf	-> Vortex_TRNG.out/m000004.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000005.ovf	-> Vortex_TRNG.out/m000005.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000006.ovf	-> Vortex_TRNG.out/m000006.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000007.ovf	-> Vortex_TRNG.out/m000007.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000009.ovf	-> Vortex_TRNG.out/m000009.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000008.ovf	-> Vortex_TRNG.out/m000008.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000010.ovf	-> Vortex_TRNG.out/m000010.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000011.ovf	-> Vortex_TRNG.out/m000011.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000012.ovf	-> Vortex_TRNG.out/m000012.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000014.ovf	-> Vortex_TRNG.out/m000014.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000015.ovf	-> Vortex_TRNG.out/m000015.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000003.ovf	-> Vortex_TRNG.out/m000003.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000016.ovf	-> Vortex_TRNG.out/m000016.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000018.ovf	-> Vortex_TRNG.out/m000018.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000019.ovf	-> Vortex_TRNG.out/m000019.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000020.ovf	-> Vortex_TRNG.out/m000020.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000013.ovf	-> Vortex_TRNG.out/m000013.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000021.ovf	-> Vortex_TRNG.out/m000021.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000023.ovf	-> Vortex_TRNG.out/m000023.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000022.ovf	-> Vortex_TRNG.out/m000022.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000024.ovf	-> Vortex_TRNG.out/m000024.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000025.ovf	-> Vortex_TRNG.out/m000025.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000026.ovf	-> Vortex_TRNG.out/m000026.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000027.ovf	-> Vortex_TRNG.out/m000027.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000028.ovf	-> Vortex_TRNG.out/m000028.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000029.ovf	-> Vortex_TRNG.out/m000029.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000030.ovf	-> Vortex_TRNG.out/m000030.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000031.ovf	-> Vortex_TRNG.out/m000031.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000033.ovf	-> Vortex_TRNG.out/m000033.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000034.ovf	-> Vortex_TRNG.out/m000034.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000035.ovf	-> Vortex_TRNG.out/m000035.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000036.ovf	-> Vortex_TRNG.out/m000036.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000017.ovf	-> Vortex_TRNG.out/m000017.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000037.ovf	-> Vortex_TRNG.out/m000037.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000038.ovf	-> Vortex_TRNG.out/m000038.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000039.ovf	-> Vortex_TRNG.out/m000039.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000040.ovf	-> Vortex_TRNG.out/m000040.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000041.ovf	-> Vortex_TRNG.out/m000041.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000042.ovf	-> Vortex_TRNG.out/m000042.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000043.ovf	-> Vortex_TRNG.out/m000043.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000045.ovf	-> Vortex_TRNG.out/m000045.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000044.ovf	-> Vortex_TRNG.out/m000044.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000046.ovf	-> Vortex_TRNG.out/m000046.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000047.ovf	-> Vortex_TRNG.out/m000047.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000048.ovf	-> Vortex_TRNG.out/m000048.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000049.ovf	-> Vortex_TRNG.out/m000049.ovf: input and output file are the same
# [fail] Vortex_TRNG.out/m000032.ovf	-> Vortex_TRNG.out/m000032.ovf: input and output file are the same
# 0 files converted,  0 skipped,  50 failed

# %% [markdown]
# Processing of ovf file to generate bits

# %%
import numpy as np
import glob
import re

# =========================
# READ OVF + GET GRID SIZE
# =========================
def read_ovf(filename):

    with open(filename, 'rb') as f:
        content = f.read()

    try:
        # ---------- ASCII ----------
        text = content.decode('utf-8')
        lines = text.split('\n')

        Nx = Ny = None

        for i, line in enumerate(lines):
            if "xnodes" in line:
                Nx = int(re.findall(r'\d+', line)[0])
            if "ynodes" in line:
                Ny = int(re.findall(r'\d+', line)[0])
            if "Begin: Data" in line:
                start = i + 1
                break

        data = np.loadtxt(lines[start:])

    except:
        # ---------- BINARY ----------
        with open(filename, 'rb') as f:
            Nx = Ny = None

            while True:
                line = f.readline()

                if b'xnodes' in line:
                    Nx = int(re.findall(rb'\d+', line)[0])
                if b'ynodes' in line:
                    Ny = int(re.findall(rb'\d+', line)[0])

                if b'Begin: Data' in line:
                    break

            # Skip control number
            f.read(4)

            data = np.fromfile(f, dtype=np.float32)

        # reshape properly
        N = Nx * Ny
        data = data[:3*N].reshape((N, 3))

    mx = data[:, 0]
    my = data[:, 1]
    mz = data[:, 2]

    return mx, my, mz, Nx, Ny


# =========================
# RESHAPE
# =========================
def reshape_field(mx, my, mz, Nx, Ny):
    mx = mx.reshape(Ny, Nx)
    my = my.reshape(Ny, Nx)
    mz = mz.reshape(Ny, Nx)
    return mx, my, mz


# =========================
# POLARITY
# =========================
def compute_polarity(mz):
    Ny, Nx = mz.shape
    cx, cy = Nx//2, Ny//2

    core = mz[cy-2:cy+3, cx-2:cx+3]
    return 1 if np.mean(core) > 0 else 0


# =========================
# CHIRALITY (STABLE)
# =========================
def compute_chirality(mx, my):
    Ny, Nx = mx.shape
    cx, cy = Nx//2, Ny//2

    r = min(cx, cy) // 2
    n = 100

    circulation = 0.0

    for k in range(n):
        theta = 2*np.pi*k/n

        x = int(cx + r*np.cos(theta))
        y = int(cy + r*np.sin(theta))

        if 0 <= x < Nx and 0 <= y < Ny:
            mx_val = mx[y, x]
            my_val = my[y, x]

            tx = -np.sin(theta)
            ty =  np.cos(theta)

            circulation += mx_val*tx + my_val*ty

    return 1 if circulation > 0 else 0


# =========================
# MAIN
# =========================
files = sorted(glob.glob("Vortex_TRNG.out/m*.ovf"))

bitstream = []

for f in files:
    mx, my, mz, Nx, Ny = read_ovf(f)

    mx, my, mz = reshape_field(mx, my, mz, Nx, Ny)

    p = compute_polarity(mz)
    c = compute_chirality(mx, my)

    bitstream.append(p)
    bitstream.append(c)

bitstring = ''.join(map(str, bitstream))

with open("bitstream.txt", "w") as f:
    f.write(bitstring)

print("✔ Bitstream generated")
print("Total bits:", len(bitstring))
print("First 100 bits:", bitstring[:100])
# Out:
# ✔ Bitstream generated
# Total bits: 100
# First 100 bits: 0101010110110101011101010101010001010101110101111101111101110101100111010101110101010101010101000101

# %% [markdown]
# Now it's up to you. Right click on the filebrowser to add a new file. Open the file and write your first mumax3 script. Run this script as demonstrated above.
